# %% [markdown]
# # **Intro, DataTypes, Import, Export**

# %%
import pandas as pd

# %%
# 2 main Data types
# Series-1D and Dataframe-2D
series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors = pd.Series(["red", "blue", "white", "black"])
colors
# Out:
# 0      red
# 1     blue
# 2    white
# 3    black
# dtype: object

# %%
car_data = pd.DataFrame({"car_make": series, "color":colors})
car_data
# Out:
#   car_make  color
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white
# 3      NaN  black

# %%
car_sales = pd.read_csv("/content/49 - car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("/content/exported-car-sales.csv", index=False)
exp = pd.read_csv("/content/exported-car-sales.csv")
exp
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # **Describing Data**

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %% [markdown]
# # Selecting and viewing

# %%
car_sales.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animals = pd.Series(["cat", "dog", "lion", "tiger", "elephant"], index=[0,3, 9, 8, 3])
animals
# Out:
# 0         cat
# 3         dog
# 9        lion
# 8       tiger
# 3    elephant
# dtype: object

# %%
animals.loc[3]
# Out:
# 3         dog
# 3    elephant
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'tiger'

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
car_sales["Price"] = car_sales["Price"].astype(str).replace('(00)$','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# # Manipulation

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("/content/54 - car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing["Odometer"].head(7)
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# Name: Odometer, dtype: float64

# %%
car_sales["Seats"] = pd.Series([5, 5, 5, 5, 5])
car_sales.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats
# 0  toyota  White         150043      4  400000    5.0
# 1   honda    Red          87899      4  500000    5.0

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats
# 8  toyota  White          60000      4  625000    5.0
# 9  nissan  White          31600      4  970000    5.0

# %%
car_sales["Fuel per 100KM"] = [6.7, 6.7, 7.8, 3.4, 5.6, 7.6, 8.9, 4.5, 8.9, 10]

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             6.7
# 1   honda    Red          87899      4   500000    5.0             6.7
# 2  toyota   Blue          32549      3   700000    5.0             7.8
# 3     bmw  Black          11179      5  2200000    5.0             3.4
# 4  nissan  White         213095      4   350000    5.0             5.6

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/ 100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             6.7
# 1   honda    Red          87899      4   500000    5.0             6.7
# 2  toyota   Blue          32549      3   700000    5.0             7.8
# 3     bmw  Black          11179      5  2200000    5.0             3.4
# 4  nissan  White         213095      4   350000    5.0             5.6
# 5  toyota  Green          99213      4   450000    5.0             7.6
# 6   honda   Blue          45698      4   750000    5.0             8.9
# 7   honda   Blue          54738      4   700000    5.0             4.5
# 8  toyota  White          60000      4   625000    5.0             8.9
# 9  nissan  White          31600      4   970000    5.0            10.0
#
#    Total Fuel Used
# 0        10052.881
# 1         5889.233
# 2         2538.822
# 3          380.086
# 4        11933.320
# 5         7540.188
# 6         4067.122
# 7         2463.210
# ...

# %%
car_sales.drop("Seats", axis=1, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             6.7
# 1   honda    Red          87899      4   500000             6.7
# 2  toyota   Blue          32549      3   700000             7.8
# 3     bmw  Black          11179      5  2200000             3.4
# 4  nissan  White         213095      4   350000             5.6
# 5  toyota  Green          99213      4   450000             7.6
# 6   honda   Blue          45698      4   750000             8.9
# 7   honda   Blue          54738      4   700000             4.5
# 8  toyota  White          60000      4   625000             8.9
# 9  nissan  White          31600      4   970000            10.0
#
#    Total Fuel Used
# 0        10052.881
# 1         5889.233
# 2         2538.822
# 3          380.086
# 4        11933.320
# 5         7540.188
# 6         4067.122
# 7         2463.210
# 8         5340.000
# 9         3160.000

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 9  nissan  White          31600      4   970000            10.0
# 3     bmw  Black          11179      5  2200000             3.4
# 4  nissan  White         213095      4   350000             5.6
# 0  toyota  White         150043      4   400000             6.7
# 5  toyota  Green          99213      4   450000             7.6
# 2  toyota   Blue          32549      3   700000             7.8
# 8  toyota  White          60000      4   625000             8.9
# 6   honda   Blue          45698      4   750000             8.9
# 1   honda    Red          87899      4   500000             6.7
# 7   honda   Blue          54738      4   700000             4.5
#
#    Total Fuel Used
# 9         3160.000
# 3          380.086
# 4        11933.320
# 0        10052.881
# 5         7540.188
# 2         2538.822
# 8         5340.000
# 6         4067.122
# 1         5889.233
# 7         2463.210

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0      9  nissan  White          31600      4   970000            10.0
# 1      3     bmw  Black          11179      5  2200000             3.4
# 2      4  nissan  White         213095      4   350000             5.6
# 3      0  toyota  White         150043      4   400000             6.7
# 4      5  toyota  Green          99213      4   450000             7.6
# 5      2  toyota   Blue          32549      3   700000             7.8
# 6      8  toyota  White          60000      4   625000             8.9
# 7      6   honda   Blue          45698      4   750000             8.9
# 8      1   honda    Red          87899      4   500000             6.7
# 9      7   honda   Blue          54738      4   700000             4.5
#
#    Total Fuel Used
# 0         3160.000
# 1          380.086
# 2        11933.320
# 3        10052.881
# 4         7540.188
# 5         2538.822
# 6         5340.000
# 7         4067.122
# ...

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  nissan  White          31600      4   970000            10.0
# 1     bmw  Black          11179      5  2200000             3.4
# 2  nissan  White         213095      4   350000             5.6
# 3  toyota  White         150043      4   400000             6.7
# 4  toyota  Green          99213      4   450000             7.6
# 5  toyota   Blue          32549      3   700000             7.8
# 6  toyota  White          60000      4   625000             8.9
# 7   honda   Blue          45698      4   750000             8.9
# 8   honda    Red          87899      4   500000             6.7
# 9   honda   Blue          54738      4   700000             4.5
#
#    Total Fuel Used
# 0         3160.000
# 1          380.086
# 2        11933.320
# 3        10052.881
# 4         7540.188
# 5         2538.822
# 6         5340.000
# 7         4067.122
# 8         5889.233
# 9         2463.210

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000             6.7
# 1   honda    Red      54936.875      4   500000             6.7
# 2  toyota   Blue      20343.125      3   700000             7.8
# 3     bmw  Black       6986.875      5  2200000             3.4
# 4  nissan  White     133184.375      4   350000             5.6
# 5  toyota  Green      62008.125      4   450000             7.6
# 6   honda   Blue      28561.250      4   750000             8.9
# 7   honda   Blue      34211.250      4   700000             4.5
# 8  toyota  White      37500.000      4   625000             8.9
# 9  nissan  White      19750.000      4   970000            10.0
#
#    Total Fuel Used
# 0        10052.881
# 1         5889.233
# 2         2538.822
# 3          380.086
# 4        11933.320
# 5         7540.188
# 6         4067.122
# 7         2463.210
# 8         5340.000
# 9         3160.000
